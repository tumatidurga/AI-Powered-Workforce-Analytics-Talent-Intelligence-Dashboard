# %% [markdown]
# <a href="https://colab.research.google.com/github/tumatidurga/AI-Powered-Workforce-Analytics-Talent-Intelligence-Dashboard/blob/main/pythoncode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Prompt Used:** Sample ppython operations like Tuple, Array, List, Dictionary.

# %% [markdown]
# **Tuple Example**

# %%
colors = ("Red", "Green", "Blue")
print("Tuple:", colors)
print("First Color:", colors[0])
print("Length:", len(colors))
# Out:
# Tuple: ('Red', 'Green', 'Blue')
# First Color: Red
# Length: 3

# %% [markdown]
# **Array Program**

# %%
import array
numbers = array.array('i', [10, 20, 30, 40])
print("Original Array:", numbers)
numbers.append(50)
print("After Append:", numbers)
print("Second Element:", numbers[1])
# Out:
# Original Array: array('i', [10, 20, 30, 40])
# After Append: array('i', [10, 20, 30, 40, 50])
# Second Element: 20

# %% [markdown]
# **List Program**

# %%
fruits = ["Apple", "Banana", "Mango", "Orange"]
print("Original List:", fruits)
fruits.append("Grapes")
print("After Append:", fruits)
fruits.remove("Banana")
print("After Remove:", fruits)
print("First Element:", fruits[0])
print("Length:", len(fruits))
# Out:
# Original List: ['Apple', 'Banana', 'Mango', 'Orange']
# After Append: ['Apple', 'Banana', 'Mango', 'Orange', 'Grapes']
# After Remove: ['Apple', 'Mango', 'Orange', 'Grapes']
# First Element: Apple
# Length: 4

# %% [markdown]
# **Dictionary** **Program**

# %%
student = {
    "Name": "Durga",
    "Age": 20,
    "Branch": "CSD"
}

print("Dictionary:", student)

print("Name:", student["Name"])

student["Age"] = 21

print("Updated Dictionary:", student)
# Out:
# Dictionary: {'Name': 'Durga', 'Age': 20, 'Branch': 'CSD'}
# Name: Durga
# Updated Dictionary: {'Name': 'Durga', 'Age': 21, 'Branch': 'CSD'}
